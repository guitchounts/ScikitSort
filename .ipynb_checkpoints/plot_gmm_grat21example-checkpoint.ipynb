# %%
# %matplotlib inline

# %% [markdown]
# # Gaussian Mixture Model Ellipsoids
#
#
# Plot the confidence ellipsoids of a mixture of two Gaussians
# obtained with Expectation Maximisation (``GaussianMixture`` class) and
# Variational Inference (``BayesianGaussianMixture`` class models with
# a Dirichlet process prior).
#
# Both models have access to five components with which to fit the data. Note
# that the Expectation Maximisation model will necessarily use all five
# components while the Variational Inference model will effectively only use as
# many as are needed for a good fit. Here we can see that the Expectation
# Maximisation model splits some components arbitrarily, because it is trying to
# fit too many components, while the Dirichlet Process model adapts it number of
# state automatically.
#
# This example doesn't show it, as we're in a low-dimensional space, but
# another advantage of the Dirichlet process model is that it can fit
# full covariance matrices effectively even when there are less examples
# per cluster than there are dimensions in the data, due to
# regularization properties of the inference algorithm.

# %%
from bokeh.plotting import figure,show
from bokeh.io import output_notebook,show,output_file,save
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="7c39318e-63c3-409e-9229-214c25bc74ab">Loading BokehJS ...</span>
#     </div>

# %%
import itertools

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture
from sklearn.decomposition import PCA

color_iter = itertools.cycle(['navy', 'c', 'cornflowerblue', 'gold',
                              'darkorange'])

# %%
from matplotlib import gridspec
import seaborn as sns

# %%
def plot_results(X, Y_, means, covariances, index, title):
    plt.figure(figsize=(20,20))  #
    splot = plt.subplot(2, 1, 1 + index)
    for i, (mean, covar, color) in enumerate(zip(
            means, covariances, color_iter)):
        v, w = linalg.eigh(covar)
        v = 2. * np.sqrt(2.) * np.sqrt(v)
        u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        if not np.any(Y_ == i):
            continue
        plt.scatter(X[Y_ == i, 0], X[Y_ == i, 1], .8, color=color)

        # Plot an ellipse to show the Gaussian component
        angle = np.arctan(u[1] / u[0])
        angle = 180. * angle / np.pi  # convert to degrees
        ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
        ell.set_clip_box(splot.bbox)
        ell.set_alpha(0.5)
        splot.add_artist(ell)

    plt.xlim([-2000,2000])
    plt.ylim([-1000,1000])
    #plt.xlim(-9., 5.)
    #plt.ylim(-3., 6.)
    #plt.xticks(())
    #plt.yticks(())
    plt.title(title)

# %%
########################### get some spikes ##############################

# %%
import os

# %%
os.getcwd()
# Out:
# '/Volumes/Mac HD/Dropbox (coxlab)/Scripts/Repositories/ScikitSort'

# %%
spiketimes_path = '/Users/guitchounts1/Documents/Ephys_Data/GRat21/636213969321601134/ChGroup_0/SpikeTimes'

spiketimes_file = open(spiketimes_path,"rb")

spiketimes = np.fromfile(spiketimes_file,dtype=np.uint64)

spiketimes_file.close
# Out:
# <function close>

# %%
spiketimes.shape
# Out:
# (15806043,)

# %%
spikes_path = '/Users/guitchounts1/Documents/Ephys_Data/GRat21/636213969321601134/ChGroup_0/Spikes'

spikes_file = open(spikes_path,"rb")

spikes = np.fromfile(spikes_file,dtype=np.int16)

spikes_file.close
# Out:
# <function close>

# %%
spikes.shape
# Out:
# (4046347008,)

# %%
plt.plot(spikes[0:256:4]) #### looks like the values are arranged [ch0,ch1,ch2,ch3;ch0,ch1,ch2,ch3...]

# %%
spikes = np.reshape(spikes,[4,64,len(spikes)/(4*64)],'F')

# %%
plt.plot(spikes[0,:,0])

# %%
spikes.shape
# Out:
# (4, 64, 15806043)

# %%
spike_vec = np.reshape(spikes,[4*64,spikes.shape[2]])

# %%
spike_vec.shape
# Out:
# (256, 15806043)

# %%
plt.plot(spike_vec[:,0])

# %%
peaks = spikes[:,31,:].T

# %%
peaks.shape
# Out:
# (15806043, 4)

# %%
peaks = peaks[ndx[0]:ndx[1]+1,:]

# %%
peaks.shape
# Out:
# (1960989, 4)

# %%
spikes = None

# %%
behaviortime_boundaries = [np.ceil(x*3e4) for x in [82719.6061261-1,97602.8439392+1]]

# %%
ndx = [np.where(spiketimes>=behaviortime_boundaries[0])[0].min(),np.where(spiketimes<=behaviortime_boundaries[1])[0].max()]

# %%
spiketimes = spiketimes[ndx[0]:ndx[1]+1] # +1 to include that last index

# %%
spike_vec = spike_vec[:,ndx[0]:ndx[1]+1]

# %%
spike_vec.shape
# Out:
# (256, 1960989)

# %%
reduced_data = PCA(n_components=4).fit_transform(spike_vec.T)

# %%
reduced_data.shape
# Out:
# (1960989, 4)

# %%
plt.scatter(reduced_data[0:100000,0],reduced_data[0:100000,1],alpha=0.1,lw = 0)
#plt.xlim([-5000,5000])
#plt.ylim([-2000,2000])

# %%
plt.scatter(peaks[0:100000,0],peaks[0:100000,1],alpha=0.1,lw = 0)

# %%
all_features = np.vstack([peaks[0:10000,:].T,ch1pcs.T,ch2pcs.T,ch3pcs.T,ch4pcs.T])

# %%
all_features.shape
# Out:
# (12, 10000)

# %%
all_pcs = np.vstack([ch1pcs.T,ch2pcs.T,ch3pcs.T,ch4pcs.T])

# %%
all_pcs.shape
# Out:
# (8, 10000)

# %%
reduced_data.shape
# Out:
# (1960989, 4)

# %%
lowest_bic = np.infty
bic = []
n_components_range = range(1, 7)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type,max_iter=1000)
        gmm.fit(reduced_data)
        bic.append(gmm.bic(reduced_data))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

bic = np.array(bic)
color_iter = itertools.cycle(['navy', 'turquoise', 'cornflowerblue',
                              'darkorange'])
clf = best_gmm
bars = []

# %%
# Plot the BIC scores
plt.figure(figsize=(20,20))
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(n_components_range) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(n_components_range)
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)

# Plot the winner
splot = plt.subplot(2, 1, 2)
Y_ = clf.predict(reduced_data)
for i, (mean, cov, color) in enumerate(zip(clf.means_, clf.covariances_,
                                           color_iter)):
    v, w = linalg.eigh(cov)
    if not np.any(Y_ == i):
        continue
    plt.scatter(reduced_data[Y_ == i, 0], reduced_data[Y_ == i, 1], .8, color=color)

    # Plot an ellipse to show the Gaussian component
    angle = np.arctan2(w[0][1], w[0][0])
    angle = 180. * angle / np.pi  # convert to degrees
    v = 2. * np.sqrt(2.) * np.sqrt(v)
    ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
    ell.set_clip_box(splot.bbox)
    ell.set_alpha(.5)
    splot.add_artist(ell)

#plt.xticks(())
#plt.yticks(())
plt.xlim([-5000,5000])
plt.ylim([-5000,5000])
plt.title('Selected GMM: full model, 2 components')
plt.subplots_adjust(hspace=.35, bottom=.02)
plt.show()

# %%
print ' yes %d asdf' % (i+1)
# Out:
#  yes 6 asdf

# %%
# Plot the winner
plt.figure(figsize=(20,20))
splot = plt.subplot(2, 1, 2)
Y_ = clf.predict(reduced_data)
for i, (mean, cov, color) in enumerate(zip(clf.means_, clf.covariances_,
                                           color_iter)):
    v, w = linalg.eigh(cov)
    if not np.any(Y_ == i):
        continue
    plt.scatter(reduced_data[Y_ == i, 0], reduced_data[Y_ == i, 2], .8, color=color)

    # Plot an ellipse to show the Gaussian component
    angle = np.arctan2(w[0][1], w[0][0])
    angle = 180. * angle / np.pi  # convert to degrees
    v = 2. * np.sqrt(2.) * np.sqrt(v)
    ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
    ell.set_clip_box(splot.bbox)
    ell.set_alpha(.5)
    splot.add_artist(ell)

#plt.xticks(())
#plt.yticks(())
plt.xlim([-5000,5000])
plt.ylim([-5000,5000])
plt.title('Selected GMM: full model, 2 components')
plt.subplots_adjust(hspace=.35, bottom=.02)
plt.show()

# %%
reduced_features = PCA(n_components=2).fit_transform(all_features.T)

# %%
reduced_features.shape
# Out:
# (10000, 2)

# %%
plt.scatter(reduced_features[:,0],reduced_features[:,1],alpha=0.1,lw = 0)
plt.xlim([-5000,5000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
plt.scatter(all_features.T[:,0],all_features.T[:,1],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-1000,600])
# Out:
# (-1000, 600)

# %%
plt.scatter(all_features.T[:,0],all_features.T[:,3],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-1000,600])
# Out:
# (-1000, 600)

# %%
plt.scatter(all_features.T[:,4],all_features.T[:,10],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
clust1spikes = np.squeeze(spike_vec[:,np.where(Y_==0)])

# %%
clust2spikes = np.squeeze(spike_vec[:,np.where(Y_==1)])

# %%
clust3spikes = np.squeeze(spike_vec[:,np.where(Y_==2)])

# %%
clust4spikes = np.squeeze(spike_vec[:,np.where(Y_==3)])

# %%
clust5spikes = np.squeeze(spike_vec[:,np.where(Y_==4)])

# %%
clust6spikes = np.squeeze(spike_vec[:,np.where(Y_==5)])

# %%
print 'num spikes in each cluster:', clust4spikes.shape
# Out:
# num spikes in each cluster: (4, 64, 1, 2522)

# %%
spikes.shape
# Out:
# (4, 64, 27813540)

# %%
clust1spikes.shape
# Out:
# (4, 64, 2949)

# %%
plt.plot(range(64),clust1spikes[0,:,1])

# %%
def plot_waveforms(spikes,clust_name):

    # spikes shape = e.g. (4, 64, 2949)

    fig = plt.figure(figsize=(20, 5)) 
    gs = gridspec.GridSpec(1, 1, width_ratios=[1, 1]) 
    ax1 = plt.subplot(gs[0])
    channels = spikes.shape[0]
    num_samples =spikes.shape[1]
    time_vec = range(channels*num_samples)

    allchans_avg = np.empty([channels*num_samples])
    allchans_std = np.empty([channels*num_samples])
    
    for i in range(channels):
         
        
        storewindows = spikes[i,:,:]  
        
        win_avg = np.mean(storewindows,axis=1)
        win_std = np.std(storewindows,axis=1)
        
        allchans_avg[i*(64):(i+1)*64] = win_avg
        allchans_std[i*(64):(i+1)*64] = win_std
        
    print len(allchans_avg)
    print type(allchans_avg)
    ax1 = errorfill(time_vec,allchans_avg,allchans_std)

    ax1 = sns.set_style("white")
    sns.despine()
    #plt.show()

    fig.tight_layout()

    fig.savefig("spikes.pdf")

# %%
def plot_tetrode(spikes,clust_name):

    # spikes shape = e.g. (256, 2949)

    fig = plt.figure(figsize=(20, 5)) 
    gs = gridspec.GridSpec(1, 1, width_ratios=[1, 1]) 
    ax1 = plt.subplot(gs[0])

    num_samples =spikes.shape[0]
    time_vec = range(num_samples)


    win_avg = np.mean(spikes,axis=1)
    win_std = np.std(spikes,axis=1)
    
    
    ax1 = errorfill(time_vec,win_avg,win_std)

    ax1 = sns.set_style("white")
    sns.despine()
    #plt.show()

    fig.tight_layout()

    fig.savefig('waveforms_cluster_' + clust_name + '.pdf')

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        #color = ax._get_lines.prop_cycler.next()
        #color= color['color']
        color = 'b'
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr

    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)

# %%
color = ax._get_lines.prop_cycler.next()

# %%
clust1spikes.shape
# Out:
# (256, 625800)

# %%
plot_tetrode(clust1spikes,'1')

# %%
plot_tetrode(clust2spikes,'2')

# %%
plot_tetrode(clust3spikes,'3')

# %%
plot_tetrode(clust4spikes,'4')

# %%
plot_tetrode(clust5spikes,'5')

# %%
plot_tetrode(clust6spikes,'6')

# %%
Y_.shape
# Out:
# (1960989,)

# %%
spiketimes.shape
# Out:
# (1960989,)

# %%
import pandas as pd

# %%
d = dict(times = spiketimes/3e4,clusters=Y_)

# %%
cluster_assignments = pd.DataFrame.from_dict(d)

# %%
cluster_assignments.to_csv('cluster_assignments.csv')

# %%
# lower = 2481562006
# upper = 2481564751

temp_idx = (cluster_assignments.times[cluster_assignments.clusters==0] < 2481564751) & (cluster_assignments.times[cluster_assignments.clusters==0] > 2481562006)

# %%
cluster_assignments[100:150] #[cluster_assignments.clusters==0]
# Out:
#      clusters         times
# 100         1  82718.956100
# 101         5  82718.959067
# 102         5  82718.960133
# 103         0  82718.961700
# 104         5  82718.963967
# 105         1  82718.965633
# 106         0  82718.968433
# 107         5  82718.970667
# 108         5  82718.973433
# 109         3  82718.982033
# 110         1  82718.983067
# 111         5  82718.984667
# 112         5  82718.990333
# 113         1  82718.994467
# 114         3  82719.002000
# 115         5  82719.015933
# 116         0  82719.019800
# 117         2  82719.024933
# 118         0  82719.026200
# 119         5  82719.030333
# 120         1  82719.032133
# 121         3  82719.035000
# 122         1  82719.042267
# 123         3  82719.044333
# 124         1  82719.046067
# 125         0  82719.047433
# 126         0  82719.053500
# 127         5  82719.055100
# 128         0  82719.057033
# 129         1  82719.060433
# 130         0  82719.064400
# 131         5  82719.067600
# 132         0  82719.069600
# 133         3  82719.071367
# 134         5  82719.076033
# 135         0  82719.077267
# 136         0  82719.082033
# 137         3  82719.097133
# 138         5  82719.099433
# 139         3  82719.106733
# 140         5  82719.108733
# 141         0  82719.116400
# 142         5  82719.118200
# 143         3  82719.122567
# 144         0  82719.133333
# 145         5  82719.138533
# 146         0  82719.140033
# 147         1  82719.141000
# 148         0  82719.148733
# 149         5  82719.150067

# %%
cluster_assignments.times.values[-1:]
# Out:
# array([ 97603.84243333])

# %%
cluster_assignments.times.irow(-1)
# Out:
# 97603.842433333339

# %%
### we want the indices of temp_idx where temp_idx is TRUE
temp_idx
# Out:
# 5          False
# 8          False
# 12         False
# 13         False
# 14         False
# 16         False
# 17         False
# 22         False
# 26         False
# 31         False
# 34         False
# 35          True
# 36          True
# 38          True
# 43          True
# 49          True
# 52          True
# 53          True
# 56          True
# 66         False
# 68         False
# 74         False
# 78         False
# 79         False
# 80         False
# 84         False
# 90         False
# 97         False
# 99         False
# 103        False
#            ...
# 1960889    False
# 1960890    False
# 1960891    False
# 1960893    False
# 1960895    False
# 1960898    False
# 1960900    False
# 1960903    False
# 1960906    False
# 1960907    False
# 1960923    False
# 1960924    False
# 1960925    False
# 1960926    False
# 1960928    False
# 1960932    False
# 1960939    False
# 1960940    False
# 1960950    False
# 1960952    False
# 1960953    False
# 1960963    False
# 1960966    False
# 1960973    False
# 1960974    False
# 1960975    False
# 1960976    False
# 1960978    False
# 1960983    False
# 1960988    False
# Name: times, dtype: bool

# %%
y = temp_idx[temp_idx==True].index.values

# %%
y
# Out:
# array([35, 36, 38, 43, 49, 52, 53, 56])

# %%
x = cluster_assignments.times[y].values

# %%
x
# Out:
# array([2481562206, 2481562302, 2481562419, 2481562764, 2481563137,
#        2481563344, 2481563414, 2481563612], dtype=uint64)

# %%
print 'blah blah %s blah %d' % ([str(len(x) for xx in x],2)
# Out:
# blah blah ['2481562206', '2481562302', '2481562419', '2481562764', '2481563137', '2481563344', '2481563414', '2481563612'] blah 2

# %%
cluster_assignments.shape
# Out:
# (1960989, 4)

# %%
cluster_assignments.clust5[0] = 10
# Out:
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
cluster_assignments.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-128-008f7b216f2e> in <module>()
# ----> 1 cluster_assignments['yes'] = []
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __setitem__(self, key, value)
#    2125         else:
#    2126             # set column
# -> 2127             self._set_item(key, value)
#    2128
#    2129     def _setitem_slice(self, key, value):
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _set_item(self, key, value)
#    2202
#    2203         self._ensure_valid_index(value)
# -> 2204         value = self._sanitize_column(key, value)
#    2205         NDFrame._set_item(self, key, value)
#    2206
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _sanitize_column(self, key, value)
#    2360
#    2361             # turn me into an ndarray
# -> 2362             value = _sanitize_index(value, self.index, copy=False)
#    2363             if not isinstance(value, (np.ndarray, Index)):
#    2364                 if isinstance(value, list) and len(value) > 0:
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/pandas/core/series.pyc in _sanitize_index(data, index, copy)
#    2577
#    2578     if len(data) != len(index):
# -> 2579         raise ValueError('Length of values does not match length of '
#    2580                          'index')
#    2581
#
# ValueError: Length of values does not match length of index

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
viz_data = reduced_data[0:40000,:]

# %%
trace = []
for i, (mean, cov, color) in enumerate(zip(clf.means_, clf.covariances_,
                                           color_iter)):
    if not np.any(Y_ == i):
        continue
    #plt.scatter(all_features.T[Y_ == i, 0], all_features.T[Y_ == i, 1], .8, color=color)

    
    
    
    temp_trace = go.Scatter3d(
        x=viz_data[Y_[0:40000] == i, 0], #x,
        y=viz_data[Y_[0:40000] == i, 1], #y,
        z=viz_data[Y_[0:40000] == i, 3], #z,
        mode='markers',
        marker=dict(
            size=1,
            line=dict(
                color= color,
                #width=0.5
            ),
            opacity=0.8
        )
    )
    trace.append(temp_trace)

data = trace
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)

# %%
color
# Out:
# 'gold'

# %%
fig = go.Figure(data=data, layout=layout)

# %%
py.iplot(fig, filename='spike_clusters_2')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~guitchounts/25.embed" height="525px" width="100%"></iframe>

# %%
import plotly

# %%
plotly.__version__
# Out:
# '1.12.9'

# %%
import plotly.tools as tls
tls.set_credentials_file(username='guitchounts', api_key='s4P3RrzIeW9GlMWJTjOD')

# %%
all_features.shape
# Out:
# (12, 10000)

# %%
bin_time = 0.025 # 25 ms bins
num_bins = np.int(1.0 / bin_time)

# %%
num_bins
# Out:
# 40

# %%
x = np.random.rand(num_bins,1)

# %%
firingrate_line = figure(width=1000, plot_height=500,y_axis_label='Firing Rate (Hz)',x_axis_label='Time (sec)')

# %%
hist,edges = np.histogram(x,bins=num_bins)

# %%
x_values = np.linspace(0,1,num_bins)

# %%
firingrate_line.line(x_values,x[:,0])

#firingrate_line.line(xx_edges,xx[:,0],color='red')

# %%
firingrate_line = None

# %%
show(firingrate_line)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="
type":"LinearAxis"}],"plot_height":500,"plot_width":1000,"renderers":[{"id":"7748b0d0-6c98-4302-8002-600f88777fec","type":"LinearAxis"},{"id":"7050b618-0b2b-4dd3-b285-d08a31dcb6fc","type":"Grid"},{"id":"b7713cb2-0578-412f-8f4d-00c2a099179e","type":"LinearAxis"},{"id":"a07d5f7f-c99a-415c-874a-d211caad17b1","type":"Grid"},{"id":"3353e376-9ec9-4276-9e9b-c7c11b0b0637","type":"BoxAnnotation"},{"id":"cae51345-4738-4bb1-bc36- ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[358]</strong>&gt;</code></p>

# %%
import scipy

# %%
xxx = scipy.interpolate.interp1d(x_values,x[:,0],kind='cubic')

# %%
xxx

# %%
new_x_values = np.linspace(0,1,num_bins*10)
x_new = xxx(new_x_values)

# %%
firingrate_line.line(new_x_values,x_new,color='red')

# %%
show(firingrate_line)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="e31102f3-1a7a-4bbd-9a94-8056cbd98e28"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e31102f3-1a7a-4bbd-9a94-8056cbd98e28");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e31102f3-1a7a-4bbd-9a94-8056cbd98e28' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a2dc283a-1910-4f2b-afd9-1ec635a876b6":{"roots":{"references":[{"attributes":{"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"}},"id":"f566e1e3-8945-4ae5-a86d-68408cb478e1","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"},"ticker":{"id":"d661f7e6-77f2-41ff-83fe-21dea82fa6d9","type":"BasicTicker"}},"id":"a07d5f7f-c99a-415c-874a-d211caad17b1","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"af53364a-bbcd-467e-8cc1-1ee34920f619","type":"Line"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"3353e376-9ec9-4276-9e9b-c7c11b0b0637","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"12c33e02-d526-425a-8008-d08caa0df6be","type":"DataRange1d"},{"attributes":{"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"}},"id":"953da47d-6160-4396-a24b-4ce425ccfeee","type":"WheelZoomTool"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"62621e81-289d-42e8-a7e1-52acdea9b191","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"44aa2d63-6eac-4277-810d-c195eb6edf1e","type":"Line"},{"attributes":{},"id":"6c526f79-20f4-449a-8691-5a7de1dfd1d2","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"72cb8b45-40f2-4613-83cf-be43dcb3d5d1","type":"ColumnDataSource"},"glyph":{"id":"40991ba8-74ee-495d-aba2-ff0264570b25","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"44aa2d63-6eac-4277-810d-c195eb6edf1e","type":"Line"},"selection_glyph":null},"id":"667aa8d3-9ce6-458f-b56d-fcb8c8fb6918","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"}},"id":"8e88afc1-2438-4db2-ae77-7115c0a9f6b0","type":"PanTool"},{"attributes":{"overlay":{"id":"3353e376-9ec9-4276-9e9b-c7c11b0b0637","type":"BoxAnnotation"},"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"}},"id":"b5aef76b-7876-4ae0-8673-0c23722e7d43","type":"BoxZoomTool"},{"attributes":{},"id":"1c58ef44-df64-4b95-9cbe-35d3daa64e65","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"cc86840f-fa69-42e2-ab47-bf3e078f6007","type":"ColumnDataSource"},"glyph":{"id":"62621e81-289d-42e8-a7e1-52acdea9b191","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"af53364a-bbcd-467e-8cc1-1ee34920f619","type":"Line"},"selection_glyph":null},"id":"cae51345-4738-4bb1-bc36-53312635b785","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"4c1cde0c-a06c-4b74-88c4-25fdea428463","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"8e88afc1-2438-4db2-ae77-7115c0a9f6b0","type":"PanTool"},{"id":"953da47d-6160-4396-a24b-4ce425ccfeee","type":"WheelZoomTool"},{"id":"b5aef76b-7876-4ae0-8673-0c23722e7d43","type":"BoxZoomTool"},{"id":"f566e1e3-8945-4ae5-a86d-68408cb478e1","type":"SaveTool"},{"id":"62468f40-18da-4659-989c-e2cbc47cdd48","type":"ResetTool"},{"id":"6e4cfdbf-cd44-4adc-8a62-6845cca27e75","type":"HelpTool"}]},"id":"c7854f8f-e751-4d12-ba6c-e7f8b5d935cf","type":"Toolbar"},{"attributes":{"axis_label":"Firing Rate (Hz)","formatter":{"id":"6c526f79-20f4-449a-8691-5a7de1dfd1d2","type":"BasicTickFormatter"},"plot":{"id":"bda03597-d4ec-4118-a9d2-98d694934a78","subtype":"Figure","type":"Plot"},"ticker":{"id":"d661f7e6-77f2-41ff-83fe-21dea82fa6d9","type":"BasicTicker"}},"id":"b7713cb2-0578-412f-8f4d-00c2a099179e","type":"LinearAxis"},{"attributes":{"callback":null,"col ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[360]</strong>&gt;</code></p>

# %%
hist,edges = np.histogram(x[:,0],bins=num_bins)

# %%
f = scipy.interpolate.interp1d(edges[:-1],hist,kind='cubic')

# %%
interp_x = np.linspace(edges[0]+bin_time/2,edges[-2]+bin_time/2,num_bins*10)

# %%
interp_y = f(interp_x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-371-f201e18cff69> in <module>()
# ----> 1 interp_y = f(interp_x)
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/scipy/interpolate/polyint.pyc in __call__(self, x)
#      77         """
#      78         x, x_shape = self._prepare_x(x)
# ---> 79         y = self._evaluate(x)
#      80         return self._finish_y(y, x_shape)
#      81
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _evaluate(self, x_new)
#     586         y_new = self._call(self, x_new)
#     587         if not self._extrapolate:
# --> 588             below_bounds, above_bounds = self._check_bounds(x_new)
#     589             if len(y_new) > 0:
#     590                 # Note fill_value must be broadcast up to the proper size
#
# /Users/guitchounts1/anaconda/lib/python2.7/site-packages/scipy/interpolate/interpolate.pyc in _check_bounds(self, x_new)
#     618                 "range.")
#     619         if self.bounds_error and above_bounds.any():
# --> 620             raise ValueError("A value in x_new is above the interpolation "
#     621                 "range.")
#     622
#
# ValueError: A value in x_new is above the interpolation range.

# %%
interp_x
# Out:
# array([ 0.01290105,  0.01529935,  0.01769765,  0.02009594,  0.02249424,
#         0.02489253,  0.02729083,  0.02968913,  0.03208742,  0.03448572,
#         0.03688401,  0.03928231,  0.04168061,  0.0440789 ,  0.0464772 ,
#         0.04887549,  0.05127379,  0.05367209,  0.05607038,  0.05846868,
#         0.06086697,  0.06326527,  0.06566357,  0.06806186,  0.07046016,
#         0.07285846,  0.07525675,  0.07765505,  0.08005334,  0.08245164,
#         0.08484994,  0.08724823,  0.08964653,  0.09204482,  0.09444312,
#         0.09684142,  0.09923971,  0.10163801,  0.1040363 ,  0.1064346 ,
#         0.1088329 ,  0.11123119,  0.11362949,  0.11602778,  0.11842608,
#         0.12082438,  0.12322267,  0.12562097,  0.12801927,  0.13041756,
#         0.13281586,  0.13521415,  0.13761245,  0.14001075,  0.14240904,
#         0.14480734,  0.14720563,  0.14960393,  0.15200223,  0.15440052,
#         0.15679882,  0.15919711,  0.16159541,  0.16399371,  0.166392  ,
#         0.1687903 ,  0.17118859,  0.17358689,  0.17598519,  0.17838348,
