# %%
# %matplotlib inline

# %% [markdown]
# # Gaussian Mixture Model Ellipsoids
#
#
# Plot the confidence ellipsoids of a mixture of two Gaussians
# obtained with Expectation Maximisation (``GaussianMixture`` class) and
# Variational Inference (``BayesianGaussianMixture`` class models with
# a Dirichlet process prior).
#
# Both models have access to five components with which to fit the data. Note
# that the Expectation Maximisation model will necessarily use all five
# components while the Variational Inference model will effectively only use as
# many as are needed for a good fit. Here we can see that the Expectation
# Maximisation model splits some components arbitrarily, because it is trying to
# fit too many components, while the Dirichlet Process model adapts it number of
# state automatically.
#
# This example doesn't show it, as we're in a low-dimensional space, but
# another advantage of the Dirichlet process model is that it can fit
# full covariance matrices effectively even when there are less examples
# per cluster than there are dimensions in the data, due to
# regularization properties of the inference algorithm.

# %%
from bokeh.plotting import figure,show
from bokeh.io import output_notebook,show,output_file,save
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3bd12421-0de6-41bf-9541-5fbae322763c">Loading BokehJS ...</span>
#     </div>

# %%
import itertools

import numpy as np
from scipy import linalg
import matplotlib.pyplot as plt
import matplotlib as mpl

from sklearn import mixture
from sklearn.decomposition import PCA

color_iter = itertools.cycle(['navy', 'c', 'cornflowerblue', 'gold',
                              'darkorange'])

# %%
from matplotlib import gridspec
import seaborn as sns

# %%
def plot_results(X, Y_, means, covariances, index, title):
    plt.figure(figsize=(20,20))  #
    splot = plt.subplot(2, 1, 1 + index)
    for i, (mean, covar, color) in enumerate(zip(
            means, covariances, color_iter)):
        v, w = linalg.eigh(covar)
        v = 2. * np.sqrt(2.) * np.sqrt(v)
        u = w[0] / linalg.norm(w[0])
        # as the DP will not use every component it has access to
        # unless it needs it, we shouldn't plot the redundant
        # components.
        if not np.any(Y_ == i):
            continue
        plt.scatter(X[Y_ == i, 0], X[Y_ == i, 1], .8, color=color)

        # Plot an ellipse to show the Gaussian component
        angle = np.arctan(u[1] / u[0])
        angle = 180. * angle / np.pi  # convert to degrees
        ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
        ell.set_clip_box(splot.bbox)
        ell.set_alpha(0.5)
        splot.add_artist(ell)

    plt.xlim([-2000,2000])
    plt.ylim([-1000,1000])
    #plt.xlim(-9., 5.)
    #plt.ylim(-3., 6.)
    #plt.xticks(())
    #plt.yticks(())
    plt.title(title)

# %%
# Number of samples per component
n_samples = 500

# Generate random sample, two components
np.random.seed(0)
C = np.array([[0., -0.1], [1.7, .4]])
X = np.r_[np.dot(np.random.randn(n_samples, 2), C),
          .7 * np.random.randn(n_samples, 2) + np.array([-6, 3])]

# Fit a Gaussian mixture with EM using five components
gmm = mixture.GaussianMixture(n_components=5, covariance_type='full').fit(X)
plot_results(X, gmm.predict(X), gmm.means_, gmm.covariances_, 0,
             'Gaussian Mixture')

# Fit a Dirichlet process Gaussian mixture using five components
dpgmm = mixture.BayesianGaussianMixture(n_components=5,
                                        covariance_type='full').fit(X)
plot_results(X, dpgmm.predict(X), dpgmm.means_, dpgmm.covariances_, 1,
             'Bayesian Gaussian Mixture with a Dirichlet process prior')

plt.show()

# %%
X.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-270dd209b8a9> in <module>()
# ----> 1 X.shape
#
# NameError: name 'X' is not defined

# %%
########################### get some spikes ##############################

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/guitchounts1/Documents/Ephys_Data/GRat18/636151800793559606/ChGroup_13'

# %%
spikes_path = '/Users/guitchounts/Documents/Data/grat21/636213969321601134/ChGroup_1/Spikes'

spikes_file = open(spikes_path,"rb")

spikes = np.fromfile(spikes_file,dtype=np.int16)

spikes_file.close
# Out:
# <function close>

# %%
spikes.shape
# Out:
# (7120266240,)

# %%
plt.plot(spikes[0:256:4]) #### looks like the values are arranged [ch0,ch1,ch2,ch3;ch0,ch1,ch2,ch3...]

# %%
spikes = np.reshape(spikes,[4,64,len(spikes)/(4*64)],'F')

# %%
plt.plot(spikes[0,:,0])

# %%
print spikes[0,:,0]
# Out:
# [ 107   66   29    0  -53  -61  -28   -8   13   -8 -119 -148  -44    0  -24
#    24  104   94   -4  -35   19   76   85    2 -106  -68   14  -42 -130 -189
#  -229 -266 -185  -77  -20  -51 -138  -73   31   60    0   16   54   58   83
#   150  116   58   56   24   25  107  177  128   20   38  121  164   59 -108
#  -158  -94  -58  -82]

# %%
peaks = spikes[:,31,:].T

# %%
peaks.shape
# Out:
# (27813540, 4)

# %%
ch23peaks = peaks[:,[1,2]]

# %%
dpgmm = mixture.BayesianGaussianMixture(n_components=5,
                                        covariance_type='full').fit(reduced_data)

# %%
plot_results(reduced_data, dpgmm.predict(reduced_data), dpgmm.means_, dpgmm.covariances_, 1,
             'Bayesian Gaussian Mixture with a Dirichlet process prior')
plt.show()

# %%
pca = PCA(n_components=2)
pca.fit(peaks)
PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
  svd_solver='auto', tol=0.0, whiten=False)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=2, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
reduced_data = PCA(n_components=2).fit_transform(peaks)

# %%
reduced_data.shape
# Out:
# (27813540, 2)

# %%
#s1 = figure(width=1000, plot_height=500, title='yes')
#s1.scatter(reduced_data[:,0],reduced_data[:,1])

# %%
#show(s1)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="83249c55-3611-4b75-a3ae-df5d0cfaa9c4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("83249c55-3611-4b75-a3ae-df5d0cfaa9c4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '83249c55-3611-4b75-a3ae-df5d0cfaa9c4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b3dd562e-750f-4113-9c68-03e8e37c29d9":{"roots":{"references":[{"attributes":{"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"}},"id":"1f33ed94-7e56-401c-af64-0b437ec69574","type":"HelpTool"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"813a45c8-5461-46b8-9086-a8a2ac4c1cdf","type":"PanTool"},{"id":"af5897bf-7105-47f6-8d6e-29206abcd3f7","type":"WheelZoomTool"},{"id":"61dd2980-dfbd-433f-be1b-0244f92d4afa","type":"BoxZoomTool"},{"id":"70385368-4b32-4d22-ab27-560e86fb41de","type":"SaveTool"},{"id":"a07f2b44-50e9-4b42-9a56-e939d1b1d767","type":"ResetTool"},{"id":"1f33ed94-7e56-401c-af64-0b437ec69574","type":"HelpTool"}]},"id":"9ad29333-d898-4e76-9646-3321bdfa92c5","type":"Toolbar"},{"attributes":{"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"aef5a854-962f-40eb-b081-e25052537dba","type":"BasicTicker"}},"id":"08d9d5a1-52de-4630-96b3-6c47e2d5a8fe","type":"Grid"},{"attributes":{"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"}},"id":"813a45c8-5461-46b8-9086-a8a2ac4c1cdf","type":"PanTool"},{"attributes":{"fill_color":{"value":"#1f77b4"},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6e7540f6-c9c4-4049-9d20-ff8d0d4fe23b","type":"Circle"},{"attributes":{"data_source":{"id":"81d579fa-493f-4a50-ac59-d963611831f5","type":"ColumnDataSource"},"glyph":{"id":"6e7540f6-c9c4-4049-9d20-ff8d0d4fe23b","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"8061fcd1-a7a7-434f-aaa5-9c62545af960","type":"Circle"},"selection_glyph":null},"id":"770f1787-a3e5-4062-bcfb-2409f3a5b8ba","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"}},"id":"a07f2b44-50e9-4b42-9a56-e939d1b1d767","type":"ResetTool"},{"attributes":{"formatter":{"id":"b8061c0a-67b2-4171-8f85-9ccbbd7ced08","type":"BasicTickFormatter"},"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"aef5a854-962f-40eb-b081-e25052537dba","type":"BasicTicker"}},"id":"0ab1b5bc-4652-40af-9405-0e8a97e57aed","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"88061340-c0aa-4b3c-8a8c-20e9764b2c95","type":"BoxAnnotation"},{"attributes":{"callback":null},"id":"0c980f35-3be3-4b1c-9dcb-e6a9feb39b51","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"988bf8ad-237d-47f1-aa3d-d1c332834c6e","subtype":"Figure","type":"Plot"},"ticker":{"id":"61b997c8-b39f-4f74-9218-91d990b3a15e","type":"BasicTicker"}},"id":"e465b207-fe8e-4823-8890-72a706e4b5ef","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8061fcd1-a7a7-434f-aaa5-9c62545af960","type":"Circle"},{"attributes":{},"id":"61b997c8-b39f-4f74-9218-91d990b3a15e","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[-342.92452503796585,-412.9795484018457,242.9936762947492,-438.7715912638683,-43.423244111569275,59.30625195523081,-414.3861397380565,158.8155730787466,127.42525802454465,-440.1067310214307,-156.1439295006139,71.7194267513343,-191.31089203013056,-93.27667651525731,-183.22984917715482,-196.92698894793568,212.8419650708031,19.35122604998541,252.08665222523723,-402.1890832937844,2.9007832657393187,-405.16435595746657,-74.31806346956802,51.07433452564898,-344.340679824729,257.6335709074727,-252.73373650899035,-20.01684582364811,62.500540896109214,89.01557192784162,56.12785620391183,-109.12068708459546,96.65351304525389,-480.07105254100 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[32]</strong>&gt;</code></p>

# %%
#output_file('scatter.html')

# %%
#save(s1,'reduced_peaks.html')

# %%
plt.scatter(reduced_data[0:100000,0],reduced_data[0:100000,1],alpha=0.1,lw = 0)
plt.xlim([-5000,5000])
plt.ylim([-600,600])
# Out:
# (-600, 600)

# %%
spikes.shape
# Out:
# (4, 64, 27813540)

# %%
ch1pcs = PCA(n_components=2).fit_transform(spikes[0,:,0:10000].T)

# %%
plt.scatter(ch1pcs[:,0],ch1pcs[:,1],alpha=0.1,lw = 0)
plt.xlim([-2000,2000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
ch2pcs = PCA(n_components=2).fit_transform(spikes[1,:,0:10000].T)

# %%
plt.scatter(ch2pcs[:,0],ch2pcs[:,1],alpha=0.1,lw = 0)
plt.xlim([-2000,2000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
ch3pcs = PCA(n_components=2).fit_transform(spikes[2,:,0:10000].T)

# %%
plt.scatter(ch3pcs[:,0],ch3pcs[:,1],alpha=0.1,lw = 0)
plt.xlim([-2000,2000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
ch4pcs = PCA(n_components=2).fit_transform(spikes[3,:,0:10000].T)

# %%
plt.scatter(ch4pcs[:,0],ch4pcs[:,1],alpha=0.1,lw = 0)
plt.xlim([-2000,2000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
all_features = np.vstack([peaks[0:10000,:].T,ch1pcs.T,ch2pcs.T,ch3pcs.T,ch4pcs.T])

# %%
all_features.shape
# Out:
# (12, 10000)

# %%
gmm = mixture.GaussianMixture()

# %%
dpgmm = mixture.BayesianGaussianMixture(n_components=1,
                                        covariance_type='full',verbose=1,weight_concentration_prior=0.01,max_iter=1000).fit(all_features.T)
# Out:
# Initialization 0
#   Iteration 0
# Initialization converged: True

# %%
plot_results(all_features.T, dpgmm.predict(all_features.T), dpgmm.means_, dpgmm.covariances_, 1,
             'Bayesian Gaussian Mixture with a Dirichlet process prior')

# %%
dpgmm.n_components
# Out:
# 10

# %%
dpgmm.means_
# Out:
# array([[ -199.51611709,  -264.51845465,  -189.09884089,  -263.6452663 ,
#            85.86061285,   -48.69282487,   195.53979966,   -17.72010766,
#            35.88433102,     3.82346139,   152.62957253,   -14.67361729],
#        [ -229.78484734,  -165.80413598,  -249.61511846,  -174.1409413 ,
#           112.78879935,   -50.58719911,    61.89690643,     7.52019529,
#           114.94521183,    28.72712066,    39.24068714,    10.56025835],
#        [  198.9103863 ,   188.99691716,   211.68069014,   200.62732206,
#          -697.45282307,   285.05492696,  -719.79467727,    12.74105602,
#          -799.0502472 ,   -18.52421852,  -773.00517657,    29.14368976],
#        [ -318.93788803,  -273.33662269,  -412.78568465,  -328.39323109,
#           386.21174294,  -164.88130303,   339.65201674,   -14.773912  ,
#           559.6143854 ,   -35.55050814,   418.89879956,   -48.22707017],
#        [ -261.86607453,  -277.87886015,  -218.62321842,  -698.87791557,
#           582.91131035,   236.07701697,   426.1526095 ,   279.65228093,
#           150.15294538,   324.65595694,  1154.45121999,   485.48331632]])

# %%
lowest_bic = np.infty
bic = []
n_components_range = range(1, 7)
cv_types = ['spherical', 'tied', 'diag', 'full']
for cv_type in cv_types:
    for n_components in n_components_range:
        # Fit a Gaussian mixture with EM
        gmm = mixture.GaussianMixture(n_components=n_components,
                                      covariance_type=cv_type,max_iter=500)
        gmm.fit(all_features.T)
        bic.append(gmm.bic(all_features.T))
        if bic[-1] < lowest_bic:
            lowest_bic = bic[-1]
            best_gmm = gmm

bic = np.array(bic)
color_iter = itertools.cycle(['navy', 'turquoise', 'cornflowerblue',
                              'darkorange'])
clf = best_gmm
bars = []

# Plot the BIC scores
plt.figure(figsize=(20,20))
spl = plt.subplot(2, 1, 1)
for i, (cv_type, color) in enumerate(zip(cv_types, color_iter)):
    xpos = np.array(n_components_range) + .2 * (i - 2)
    bars.append(plt.bar(xpos, bic[i * len(n_components_range):
                                  (i + 1) * len(n_components_range)],
                        width=.2, color=color))
plt.xticks(n_components_range)
plt.ylim([bic.min() * 1.01 - .01 * bic.max(), bic.max()])
plt.title('BIC score per model')
xpos = np.mod(bic.argmin(), len(n_components_range)) + .65 +\
    .2 * np.floor(bic.argmin() / len(n_components_range))
plt.text(xpos, bic.min() * 0.97 + .03 * bic.max(), '*', fontsize=14)
spl.set_xlabel('Number of components')
spl.legend([b[0] for b in bars], cv_types)

# Plot the winner
splot = plt.subplot(2, 1, 2)
Y_ = clf.predict(all_features.T)
for i, (mean, cov, color) in enumerate(zip(clf.means_, clf.covariances_,
                                           color_iter)):
    v, w = linalg.eigh(cov)
    if not np.any(Y_ == i):
        continue
    plt.scatter(all_features.T[Y_ == i, 0], all_features.T[Y_ == i, 1], .8, color=color)

    # Plot an ellipse to show the Gaussian component
    angle = np.arctan2(w[0][1], w[0][0])
    angle = 180. * angle / np.pi  # convert to degrees
    v = 2. * np.sqrt(2.) * np.sqrt(v)
    ell = mpl.patches.Ellipse(mean, v[0], v[1], 180. + angle, color=color)
    ell.set_clip_box(splot.bbox)
    ell.set_alpha(.5)
    splot.add_artist(ell)

#plt.xticks(())
#plt.yticks(())
plt.xlim([-1000,1000])
plt.ylim([-750,750])
plt.title('Selected GMM: full model, 2 components')
plt.subplots_adjust(hspace=.35, bottom=.02)
plt.show()

# %%
reduced_features = PCA(n_components=2).fit_transform(all_features.T)

# %%
reduced_features.shape
# Out:
# (10000, 2)

# %%
plt.scatter(reduced_features[:,0],reduced_features[:,1],alpha=0.1,lw = 0)
plt.xlim([-5000,5000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
plt.scatter(all_features.T[:,0],all_features.T[:,1],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-1000,600])
# Out:
# (-1000, 600)

# %%
plt.scatter(all_features.T[:,0],all_features.T[:,3],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-1000,600])
# Out:
# (-1000, 600)

# %%
plt.scatter(all_features.T[:,4],all_features.T[:,10],alpha=0.1,lw = 0)
plt.xlim([-1000,1000])
plt.ylim([-2000,2000])
# Out:
# (-2000, 2000)

# %%
clust1spikes = np.squeeze(spikes[:,:,np.where(Y_==0)])

# %%
clust2spikes = np.squeeze(spikes[:,:,np.where(Y_==1)])

# %%
clust3spikes = np.squeeze(spikes[:,:,np.where(Y_==2)])

# %%
clust4spikes = np.squeeze(spikes[:,:,np.where(Y_==3)])

# %%
clust5spikes = np.squeeze(spikes[:,:,np.where(Y_==4)])

# %%
print 'num spikes in each cluster:', clust4spikes.shape
# Out:
# num spikes in each cluster: (4, 64, 1, 2522)

# %%
spikes.shape
# Out:
# (4, 64, 27813540)

# %%
clust1spikes.shape
# Out:
# (4, 64, 2949)

# %%
plt.plot(range(64),clust1spikes[0,:,1])

# %%
def plot_waveforms(spikes,clust_name):

    # spikes shape = e.g. (4, 64, 2949)

    fig = plt.figure(figsize=(10, 10)) 
    gs = gridspec.GridSpec(1, 1, width_ratios=[1, 1]) 
    ax1 = plt.subplot(gs[0])
    channels = spikes.shape[0]
    num_samples =spikes.shape[1]
    time_vec = range(channels*num_samples)

    allchans_avg = np.empty([channels*num_samples])
    allchans_std = np.empty([channels*num_samples])
    
    for i in range(channels):
         
        
        storewindows = spikes[i,:,:]  
        np.append()
        win_avg = np.mean(storewindows,axis=1)
        win_std = np.std(storewindows,axis=1)
        
        allchans_avg.extend(win_avg)
        allchans_std.extend(win_std)
    print len(allchans_avg)
    print type(allchans_avg)
    ax1 = errorfill(time_vec,allchans_avg,allchans_std)

    ax1 = sns.set_style("white")
    sns.despine()
    #plt.show()

    fig.tight_layout()

    fig.savefig("spikes.pdf")

# %%
def errorfill(x, y, yerr, color=None, alpha_fill=0.3, ax=None):
    ax = ax if ax is not None else plt.gca()
    if color is None:
        color = ax._get_lines.prop_cycler.next()
        color= color['color']
    if np.isscalar(yerr) or len(yerr) == len(y):
        ymin = y - yerr
        ymax = y + yerr
    elif len(yerr) == 2:
        ymin, ymax = yerr

    ax.plot(x, y, color=color)
    ax.fill_between(x, ymax, ymin, color=color, alpha=alpha_fill)

# %%
color = ax._get_lines.prop_cycler.next()

# %%
plot_waveforms(clust5spikes,'0')
# Out:
# 256
# <type 'list'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-178-64f527ba41d6> in <module>()
# ----> 1 plot_waveforms(clust5spikes,'0')
#
# <ipython-input-176-c5b12dd6ee14> in plot_waveforms(spikes, clust_name)
#      25     print len(allchans_avg)
#      26     print type(allchans_avg)
# ---> 27     ax1 = errorfill(time_vec,allchans_avg,allchans_std)
#      28
#      29     ax1 = sns.set_style("white")
#
# <ipython-input-110-f584cbde8622> in errorfill(x, y, yerr, color, alpha_fill, ax)
#       5         color= color['color']
#       6     if np.isscalar(yerr) or len(yerr) == len(y):
# ----> 7         ymin = y - yerr
#       8         ymax = y + yerr
#       9     elif len(yerr) == 2:
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'
